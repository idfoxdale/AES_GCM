# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git

# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# 4 loras Install any additional Analog Madnes
# !wget -O /content/Fooocus/models/loras/UpskirtNakedXL.safetensors https://civitai.com/api/download/models/405074?type=Model&format=SafeTensor

# %%
# Install any additional Fooocus dependencies e.g. upscaler
# !wget -O /content/Fooocus/models/upscale_models/fooocus_upscaler_s409985e5.bin https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_upscaler_s409985e5.bin?download=true

# %%
# 1 model you want to run and save it to the checkpoint folder
# !wget -O /content/Fooocus/models/checkpoints/3dAnimationDiffusion_v10.safetensors https://civitai.com/api/download/models/128046?type=Model&format=SafeTensor&size=pruned&fp=fp16

# %%
# 2 model you want to run and save it to the checkpoint folder
# !wget -O /content/Fooocus/models/checkpoints/SDXLFaetastic_v24.safetensors https://civitai.com/api/download/models/291443?type=Model&format=SafeTensor&size=pruned&fp=fp16

# %%
# 2 loras Install any additional Fooocus
# !wget -O /content/Fooocus/models/loras/SDXLFaeTastic2400.safetensors https://civitai.com/api/download/models/293991?type=Model&format=SafeTensor

# %%
# 3 model you want to run and save it to the checkpoint Analog Madnes folder
# !wget -O /content/Fooocus/models/checkpoints/analogMadness_v70.safetensors https://civitai.com/api/download/models/261539?type=Model&format=SafeTensor&size=full&fp=fp16

# %%
# 3 loras Install any additional Analog Madnes
# !wget -O /content/Fooocus/models/loras/onoff4.safetensors https://civitai.com/api/download/models/132739?type=Model&format=SafeTensor

# %%
# 4 lorasxx Install any additional Analog Madnes
# !wget -O /content/Fooocus/models/loras/UpskirtNakedXL.safetensors https://civitai.com/api/download/models/405074?type=Model&format=SafeTensor

# %%
# 5 lorasxx Install any additional Analog Madnes
# !wget -O /content/Fooocus/models/loras/Expressive_H-000001.safetensors https://civitai.com/api/download/models/382152?type=Model&format=SafeTensor

# %%
# 5 lorasxx Install any additional Tenacles
# !wget -O /content/Fooocus/models/loras/Tentacles_troubles_in_the_swamps.safetensors https://civitai.com/api/download/models/324994?type=Model&format=SafeTensor

# %%
# 4 model you want to run and save it to the checkpoint folder Dynavision
# !wget -O /content/Fooocus/models/checkpoints/dynavisionXLAllInOneStylized_releaseV0610Bakedvae.safetensors https://civitai.com/api/download/models/297740?type=Model&format=SafeTensor&size=pruned&fp=fp16

# %%
# 6 model you want to run and save it to the checkpoint folder PonyDiffusion
# !wget -O /content/Fooocus/models/checkpoints/ponyDiffusionV6XL_v6StartWithThisOne.safetensors https://civitai.com/api/download/models/290640?type=Model&format=SafeTensor&size=pruned&fp=fp16

# %%
# 6 loras Pony Install any additional fot ponyStyles

# !wget -O /content/Fooocus/models/loras/Concept Art Twilight Style SDXL_LoRA_Pony Diffusion V6 XL.safetensors https://civitai.com/api/download/models/330475?type=Model&format=SafeTensor

# %%
# 6 loras PonyInstall any additional Analog Madnes
# !wget -O /content/Fooocus/models/loras/Anime Summer Night Style SDXL_LoRA_Pony Diffusion V6 XL.safetensors https://civitai.com/api/download/models/374041?type=Model&format=SafeTensor

# %%
# 6 loras Pony Install any additional Sinfully

# !wget -O /content/Fooocus/models/loras/Esinfully_stylish_SDXL.safetensors https://civitai.com/api/download/models/407532?type=Model&format=SafeTensor

# %%
# 5 model you want to run and save it to the checkpoint folder zavychromax
# !wget -O /content/Fooocus/models/checkpoints/zavychromaxl_v60.safetensors https://civitai.com/api/download/models/416867?type=Model&format=SafeTensor&size=full&fp=fp16

# %%
# 5 model you want to run and save it to the checkpoint folder xvision_11.safetensors
# !wget -O /content/Fooocus/models/checkpoints/xvision_11.safetensors https://civitai.com/api/download/models/342509?type=Model&format=SafeTensor&size=full&fp=fp32

# %%
# 6 model you want to run and save it to the checkpoint folder xvision_11.safetensors
# !wget -O /content/Fooocus/models/checkpoints/ivisionIllustration_ivision10.safetensors https://civitai.com/api/download/models/389185

# %%
# 6 model you want to run and save it to the checkpoint folder mklanArtVersion_181.safetensors
# !wget -O /content/Fooocus/models/checkpoints/mklanArtVersion_181.safetensors https://civitai.com/api/download/models/363695

# %%
# Run Fooocus!
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.3.1
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 15102 MB, total RAM 12979 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# 2024-04-07 09:46:35.804535: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-07 09:46:35.804588: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
